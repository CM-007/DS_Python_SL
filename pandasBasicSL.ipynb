# %% [markdown]
# <a href="https://colab.research.google.com/github/CM-007/DS_Python_SL/blob/main/pandasBasicSL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Pandas Self Study**

# %% [markdown]
# Importing Librarys

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating Data Frame object

# %%
pd.DataFrame({'A':[1,2,3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %% [markdown]
# **Object Creation**

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# **Creating a DataFrame by passing a NumPy array, with a datetime index using date_range() and labeled columns:**

# %%
dates =pd.date_range('20230620',periods=6)
dates
# Out:
# DatetimeIndex(['2023-06-20', '2023-06-21', '2023-06-22', '2023-06-23',
#                '2023-06-24', '2023-06-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-06-20  0.252008  0.732983  0.863945  0.471514
# 2023-06-21  0.478707  0.735768  0.576918  0.622748
# 2023-06-22  0.979894  0.084016  0.663203  0.219056
# 2023-06-23  0.180149  0.872180  0.526638  0.246744
# 2023-06-24  0.056315  0.496354  0.498475  0.780256
# 2023-06-25  0.954740  0.132602  0.441115  0.349760

# %% [markdown]
# **Creating a DataFrame by passing a dictionary of objects that can be converted into a series-like structure:**

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",

    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# **The columns of the resulting DataFrame have different dtypes:**

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # **Viewing data**

# %%
df.head()
# Out:
#                    A         B         C         D
# 2023-06-20  0.252008  0.732983  0.863945  0.471514
# 2023-06-21  0.478707  0.735768  0.576918  0.622748
# 2023-06-22  0.979894  0.084016  0.663203  0.219056
# 2023-06-23  0.180149  0.872180  0.526638  0.246744
# 2023-06-24  0.056315  0.496354  0.498475  0.780256

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2023-06-23  0.180149  0.872180  0.526638  0.246744
# 2023-06-24  0.056315  0.496354  0.498475  0.780256
# 2023-06-25  0.954740  0.132602  0.441115  0.349760

# %%
df.index
# Out:
# DatetimeIndex(['2023-06-20', '2023-06-21', '2023-06-22', '2023-06-23',
#                '2023-06-24', '2023-06-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# ## **describe() shows a quick statistic summary of your data:**

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.483635  0.508984  0.595049  0.448346
# std    0.399148  0.333448  0.151645  0.220931
# min    0.056315  0.084016  0.441115  0.219056
# 25%    0.198114  0.223540  0.505516  0.272498
# 50%    0.365357  0.614668  0.551778  0.410637
# 75%    0.835732  0.735072  0.641632  0.584940
# max    0.979894  0.872180  0.863945  0.780256

# %% [markdown]
# ### **Transposing your data:**

# %%
df.T
# Out:
#    2023-06-20  2023-06-21  2023-06-22  2023-06-23  2023-06-24  2023-06-25
# A    0.252008    0.478707    0.979894    0.180149    0.056315    0.954740
# B    0.732983    0.735768    0.084016    0.872180    0.496354    0.132602
# C    0.863945    0.576918    0.663203    0.526638    0.498475    0.441115
# D    0.471514    0.622748    0.219056    0.246744    0.780256    0.349760

# %% [markdown]
# ## **DataFrame.sort_index() sorts by an axis:**

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2023-06-20  0.471514  0.863945  0.732983  0.252008
# 2023-06-21  0.622748  0.576918  0.735768  0.478707
# 2023-06-22  0.219056  0.663203  0.084016  0.979894
# 2023-06-23  0.246744  0.526638  0.872180  0.180149
# 2023-06-24  0.780256  0.498475  0.496354  0.056315
# 2023-06-25  0.349760  0.441115  0.132602  0.954740

# %% [markdown]
# ## **DataFrame.sort_values() sorts by values:**

# %%
df.sort_values(by="B",ascending=False)
# Out:
#                    A         B         C         D
# 2023-06-23  0.180149  0.872180  0.526638  0.246744
# 2023-06-21  0.478707  0.735768  0.576918  0.622748
# 2023-06-20  0.252008  0.732983  0.863945  0.471514
# 2023-06-24  0.056315  0.496354  0.498475  0.780256
# 2023-06-25  0.954740  0.132602  0.441115  0.349760
# 2023-06-22  0.979894  0.084016  0.663203  0.219056

# %% [markdown]
# ### **Selecting a single column, which yields a Series, equivalent to df.A:**

# %%
df.A
df['A']
# Out:
# 2023-06-20    0.252008
# 2023-06-21    0.478707
# 2023-06-22    0.979894
# 2023-06-23    0.180149
# 2023-06-24    0.056315
# 2023-06-25    0.954740
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2023-06-20  0.252008  0.732983  0.863945  0.471514
# 2023-06-21  0.478707  0.735768  0.576918  0.622748
# 2023-06-22  0.979894  0.084016  0.663203  0.219056

# %%
df.loc[:,["A"]]
# Out:
#                    A
# 2023-06-20  0.252008
# 2023-06-21  0.478707
# 2023-06-22  0.979894
# 2023-06-23  0.180149
# 2023-06-24  0.056315
# 2023-06-25  0.954740

# %%
df[df["A"]>0.6]
# Out:
#                    A         B         C         D
# 2023-06-22  0.979894  0.084016  0.663203  0.219056
# 2023-06-25  0.954740  0.132602  0.441115  0.349760

# %%
df[df >0.1]
# Out:
#                    A         B         C         D
# 2023-06-20  0.252008  0.732983  0.863945  0.471514
# 2023-06-21  0.478707  0.735768  0.576918  0.622748
# 2023-06-22  0.979894       NaN  0.663203  0.219056
# 2023-06-23  0.180149  0.872180  0.526638  0.246744
# 2023-06-24       NaN  0.496354  0.498475  0.780256
# 2023-06-25  0.954740  0.132602  0.441115  0.349760

# %%
df3 =df.copy()
df3["E"] = ['One','Two','Three','Four','Three','Four']
df3
# Out:
#                    A         B         C         D      E
# 2023-06-20  0.252008  0.732983  0.863945  0.471514    One
# 2023-06-21  0.478707  0.735768  0.576918  0.622748    Two
# 2023-06-22  0.979894  0.084016  0.663203  0.219056  Three
# 2023-06-23  0.180149  0.872180  0.526638  0.246744   Four
# 2023-06-24  0.056315  0.496354  0.498475  0.780256  Three
# 2023-06-25  0.954740  0.132602  0.441115  0.349760   Four

# %%
df3[df3["E"].isin(["Two"])]
# Out:
#                    A         B         C         D    E
# 2023-06-21  0.478707  0.735768  0.576918  0.622748  Two

# %% [markdown]
# # **Oprations **

# %%
df.mean()
# Out:
# A    0.483635
# B    0.508984
# C    0.595049
# D    0.448346
# dtype: float64

# %%
df.value_counts()
# Out:
# A         B         C         D
# 0.056315  0.496354  0.498475  0.780256    1
# 0.180149  0.872180  0.526638  0.246744    1
# 0.252008  0.732983  0.863945  0.471514    1
# 0.478707  0.735768  0.576918  0.622748    1
# 0.954740  0.132602  0.441115  0.349760    1
# 0.979894  0.084016  0.663203  0.219056    1
# dtype: int64
